# %%
import numpy as np
from matplotlib import pyplot as plt
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_d9477dd87e4d467b9d12931711cb1ed9 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='0BHcNWsLKzVcd3s0BQ3DoixUOV8K7sE5MW42_Wh-iBPg',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_d9477dd87e4d467b9d12931711cb1ed9.get_object(Bucket='crimerateprediction-donotdelete-pr-zvonl8idiq81uv',Key='Crime rate Prediction.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

dataset = pd.read_csv(body)
dataset.head()

import pandas as pd

# %%
dataset.corr()
# Out:
#                      report_year  population  robberies  robberies_percapita
# report_year             1.000000    0.066498  -0.095505            -0.230710
# population              0.066498    1.000000   0.805544             0.097596
# robberies              -0.095505    0.805544   1.000000             0.412895
# robberies_percapita    -0.230710    0.097596   0.412895             1.000000

# %%
dataset
# Out:
#       report_year  population  robberies  robberies_percapita
# 0            1975    286238.0      819.0               286.13
# 1            1975    112478.0      113.0               100.46
# 2            1975    490584.0     3887.0               792.32
# 3            1975    116656.0      171.0               146.58
# 4            1975    300400.0      529.0               176.10
# 5            1975    642154.0      750.0               116.79
# 6            1975    864100.0     9055.0              1047.91
# 7            1975    616120.0     7778.0              1262.42
# 8            1975    422276.0     2340.0               554.14
# 9            1975    262103.0      822.0               313.62
# 10           1975   3150000.0    22171.0               703.84
# 11           1975    433367.0     1745.0               402.66
# 12           1975    659931.0     7100.0              1075.87
# 13           1975    572797.0     2402.0               419.35
# ...

# %%
dataset.dtypes
# Out:
# report_year              int64
# population             float64
# robberies              float64
# robberies_percapita    float64
# dtype: object

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=2829, step=1)

# %%
dataset.describe()
# Out:
#        report_year    population      robberies  robberies_percapita
# count  2829.000000  2.760000e+03    2754.000000          2754.000000
# mean   1995.000000  7.956981e+05    4000.245098           459.968112
# std      11.834251  1.012451e+06    8653.902965           340.903534
# min    1975.000000  1.007630e+05      83.000000            11.460000
# 25%    1985.000000  3.779310e+05    1032.000000           210.242500
# 50%    1995.000000  5.366145e+05    1940.000000           374.400000
# 75%    2005.000000  8.168558e+05    3609.750000           612.005000
# max    2015.000000  8.550861e+06  107475.000000          2337.520000

# %%
dataset.sort_index(axis=1,ascending="false")
# Out:
#       population  report_year  robberies  robberies_percapita
# 0       286238.0         1975      819.0               286.13
# 1       112478.0         1975      113.0               100.46
# 2       490584.0         1975     3887.0               792.32
# 3       116656.0         1975      171.0               146.58
# 4       300400.0         1975      529.0               176.10
# 5       642154.0         1975      750.0               116.79
# 6       864100.0         1975     9055.0              1047.91
# 7       616120.0         1975     7778.0              1262.42
# 8       422276.0         1975     2340.0               554.14
# 9       262103.0         1975      822.0               313.62
# 10     3150000.0         1975    22171.0               703.84
# 11      433367.0         1975     1745.0               402.66
# 12      659931.0         1975     7100.0              1075.87
# 13      572797.0         1975     2402.0               419.35
# ...

# %%
 dataset.head()
# Out:
#    report_year  population  robberies  robberies_percapita
# 0         1975    286238.0      819.0               286.13
# 1         1975    112478.0      113.0               100.46
# 2         1975    490584.0     3887.0               792.32
# 3         1975    116656.0      171.0               146.58
# 4         1975    300400.0      529.0               176.10

# %%
dataset.isnull().any()
# Out:
# report_year            False
# population              True
# robberies               True
# robberies_percapita     True
# dtype: bool

# %%
dataset["population"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2799    False
# 2800    False
# 2801    False
# 2802    False
# 2803    False
# 2804    False
# 2805    False
# 2806    False
# 2807    False
# 2808    False
# 2809    False
# 2810    False
# 2811    False
# 2812    False
# 2813    False
# 2814    False
# 2815    False
# 2816    False
# 2817    False
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# 2823    False
# 2824    False
# 2825    False
# 2826    False
# 2827    False
# 2828     True
# ...

# %%
dataset.fillna(value=dataset.mean(),inplace=True)

# %%
dataset['population'].fillna(value=dataset['population'].mean(),inplace=True)

# %%
dataset["robberies"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2799    False
# 2800    False
# 2801    False
# 2802    False
# 2803    False
# 2804    False
# 2805    False
# 2806    False
# 2807    False
# 2808    False
# 2809    False
# 2810    False
# 2811    False
# 2812    False
# 2813    False
# 2814    False
# 2815    False
# 2816    False
# 2817    False
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# 2823    False
# 2824    False
# 2825    False
# 2826    False
# 2827    False
# 2828    False
# ...

# %%
dataset.fillna(value=dataset.mean(),inplace=True)

# %%
dataset['robberies'].fillna(value=dataset['robberies'].mean(),inplace=True)

# %%
dataset["robberies_percapita"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2799    False
# 2800    False
# 2801    False
# 2802    False
# 2803    False
# 2804    False
# 2805    False
# 2806    False
# 2807    False
# 2808    False
# 2809    False
# 2810    False
# 2811    False
# 2812    False
# 2813    False
# 2814    False
# 2815    False
# 2816    False
# 2817    False
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# 2823    False
# 2824    False
# 2825    False
# 2826    False
# 2827    False
# 2828    False
# ...

# %%
dataset.fillna(value=dataset.mean(),inplace=True)

# %%
dataset['robberies_percapita'].fillna(value=dataset['robberies_percapita'].mean(),inplace=True)

# %%
dataset.isnull().any()
# Out:
# report_year            False
# population             False
# robberies              False
# robberies_percapita    False
# dtype: bool

# %%
x=dataset.iloc[:,0:3]

# %%
x
# Out:
#       report_year    population     robberies
# 0            1975  2.862380e+05    819.000000
# 1            1975  1.124780e+05    113.000000
# 2            1975  4.905840e+05   3887.000000
# 3            1975  1.166560e+05    171.000000
# 4            1975  3.004000e+05    529.000000
# 5            1975  6.421540e+05    750.000000
# 6            1975  8.641000e+05   9055.000000
# 7            1975  6.161200e+05   7778.000000
# 8            1975  4.222760e+05   2340.000000
# 9            1975  2.621030e+05    822.000000
# 10           1975  3.150000e+06  22171.000000
# 11           1975  4.333670e+05   1745.000000
# 12           1975  6.599310e+05   7100.000000
# 13           1975  5.727970e+05   2402.000000
# 14           1975  8.646650e+05   3386.000000
# 15           1975  5.081400e+05   2568.000000
# 16           1975  1.432444e+06  21317.000000
# 17           1975  3.690000e+05    840.000000
# 18           1975  4.879050e+05    433.000000
# ...

# %%
x=dataset.iloc[:,0:3].values

# %%
x
# Out:
# array([[  1.97500000e+03,   2.86238000e+05,   8.19000000e+02],
#        [  1.97500000e+03,   1.12478000e+05,   1.13000000e+02],
#        [  1.97500000e+03,   4.90584000e+05,   3.88700000e+03],
#        ...,
#        [  2.01500000e+03,   6.72228000e+05,   3.40400000e+03],
#        [  2.01500000e+03,   3.89824000e+05,   7.33000000e+02],
#        [  2.01500000e+03,   7.95698089e+05,   4.00024510e+03]])

# %%
y=dataset.iloc[:,-1:]

# %%
y
# Out:
#       robberies_percapita
# 0              286.130000
# 1              100.460000
# 2              792.320000
# 3              146.580000
# 4              176.100000
# 5              116.790000
# 6             1047.910000
# 7             1262.420000
# 8              554.140000
# 9              313.620000
# 10             703.840000
# 11             402.660000
# 12            1075.870000
# 13             419.350000
# 14             391.600000
# 15             505.370000
# 16            1488.160000
# 17             227.640000
# 18              88.750000
# 19             316.570000
# 20             321.250000
# 21             148.880000
# 22             467.960000
# 23             614.210000
# 24             318.170000
# 25             629.940000
# 26             539.760000
# 27             574.890000
# 28             298.660000
# 29             534.460000
# ...                   ...
# 2799            52.300000
# 2800           380.480000
# 2801           198.180000
# ...

# %%
y=dataset.iloc[:,-1:].values

# %%
y
# Out:
# array([[ 286.13      ],
#        [ 100.46      ],
#        [ 792.32      ],
#        ...,
#        [ 506.38      ],
#        [ 188.03      ],
#        [ 459.96811184]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=0)

# %%
x_train
# Out:
# array([[  2.00500000e+03,   1.27214800e+06,   1.86200000e+03],
#        [  1.99800000e+03,   7.35774500e+06,   3.93590000e+04],
#        [  1.98300000e+03,   3.82373000e+05,   1.40100000e+03],
#        ...,
#        [  1.99800000e+03,   5.23000000e+05,   3.60600000e+03],
#        [  2.01200000e+03,   1.92465000e+05,   3.17000000e+02],
#        [  2.01400000e+03,   8.47393800e+06,   1.65810000e+04]])

# %%
x_test
# Out:
# array([[  1.97800000e+03,   3.08669900e+06,   1.52330000e+04],
#        [  1.98900000e+03,   3.72282000e+05,   1.42800000e+03],
#        [  2.00000000e+03,   3.90007000e+05,   8.75000000e+02],
#        ...,
#        [  1.98500000e+03,   7.06062000e+05,   1.23700000e+03],
#        [  2.01200000e+03,   3.36952000e+05,   4.82000000e+02],
#        [  1.99700000e+03,   3.96843000e+05,   1.79400000e+03]])

# %%
y_train
# Out:
# array([[ 146.37],
#        [ 534.93],
#        [ 366.4 ],
#        ...,
#        [ 689.48],
#        [ 164.71],
#        [ 195.67]])

# %%
y_test
# Out:
# array([[  493.5       ],
#        [  383.58      ],
#        [  224.35      ],
#        [  574.88      ],
#        [  434.42      ],
#        [  224.49      ],
#        [  467.41      ],
#        [  181.74      ],
#        [  379.16      ],
#        [  363.43      ],
#        [ 1049.28      ],
#        [  290.05      ],
#        [ 1094.36      ],
#        [  417.17      ],
#        [  203.75      ],
#        [  688.94      ],
#        [  221.97      ],
#        [  204.26      ],
#        [  606.1       ],
#        [  541.12      ],
#        [  163.36      ],
#        [  987.8       ],
#        [  373.79      ],
#        [  596.2       ],
#        [  364.28      ],
#        [  391.82      ],
#        [  650.47      ],
#        [  547.88      ],
#        [  120.13      ],
#        [  458.54      ],
#        [  185.67      ],
#        [  179.63      ],
#        [  459.96811184],
#        [  265.04      ],
#        [   92.12      ],
#        [  411.23      ],
#        [  703.84      ],
# ...

# %%
x.shape
# Out:
# (2829, 3)

# %%
y.shape
# Out:
# (2829, 1)

# %%
from sklearn.linear_model import LinearRegression
mr=LinearRegression()

# %%
mr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.scatter(x_train[:,2],y_train,color='green')

# %%
plt.scatter(x_test[:,2],y_test)

# %%
y_predict=mr.predict(x_test)

# %%
y_predict
# Out:
# array([[  410.55514253],
#        [  476.40757146],
#        [  418.40434073],
#        [  518.10170149],
#        [  497.30627985],
#        [  405.99559402],
#        [  501.80135399],
#        [  438.4442686 ],
#        [  359.07694508],
#        [  401.59696479],
#        [  668.38153957],
#        [  418.14484973],
#        [  685.95320379],
#        [  416.15934941],
#        [  392.99491063],
#        [  529.82081997],
#        [  451.60879486],
#        [  294.98417405],
#        [  497.83660861],
#        [  518.45748121],
#        [  379.40783952],
#        [  937.01927551],
#        [  451.94473544],
#        [  529.26530832],
#        [  470.80748203],
#        [  394.34350643],
#        [  452.58226463],
#        [  515.86561825],
#        [  333.33749183],
#        [  508.74551425],
#        [  246.94002553],
#        [  250.97400595],
#        [  406.11367909],
#        [ -588.3574331 ],
#        [  526.47364887],
#        [  448.413012  ],
#        [  661.77298697],
# ...

# %%
y_predict=mr.predict(x_train)

# %%
y_predict
# Out:
# array([[ 241.55717447],
#        [ 281.79066943],
#        [ 491.47130567],
#        ...,
#        [ 495.53101974],
#        [ 405.48724231],
#        [-858.99176794]])

# %%
#3D showing 
import seaborn as sns

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
from matplotlib.pyplot import*
x_train=[1,3,5,7]
y_train=[2,4,6,8]
x_test=[3,6,9,12]
y_test=[4,8,12,16]
bar(x_train,y_train,label="plot1")
bar(x_test,y_test,label="plot2")
xlabel("CRIME")
ylabel("PER-CAPITA")
title("PREDICTING CRIME RATE DURING YEARS")
legend()
show()

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 2019-05-22 11:12:30,752 - watson_machine_learning_client.metanames - WARNING - 'AUTHOR_EMAIL' meta prop is deprecated. It will be ignored.

# %%
wml_credentials = {
    "instance_id" : "f7a4026d-88ec-4375-99fe-35bc417dda3e",
    "password" : "5a5ddb83-7f3e-4c6b-b6c6-80ec8b8525d2",
    "url" : "https://eu-gb.ml.cloud.ibm.com",
    "username" : "16eb5566-0734-4cdf-a06b-db599085465f",
    "access_key" : "b3N_54ZPcKSUvdPmW7aPzoHNGdnBvQ7HiZ3XMw002PAf"
}

# %%
client = WatsonMachineLearningAPIClient(wml_credentials)

# %%
model_props = { client.repository.ModelMetaNames.AUTHOR_NAME: "IBM",
                client.repository.ModelMetaNames.AUTHOR_EMAIL:" balasandeepboppana@gmail.com",
                client.repository.ModelMetaNames.NAME:"Crime Rate Prediction"
}

# %%
model_artifact = client.repository.store_model(mr,meta_props= model_props)

# %%
published_model_uid = client.repository.get_model_uid(model_artifact)

# %%
created_deployment = client.deployments.create(published_model_uid,name="Crime Rate Prediction")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '753e8093-3b52-4833-a73f-9c0f16b2e4b5' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='968cd041-732e-45f8-84f1-6744ba99dfb9'
# ------------------------------------------------------------------------------------------------

# %%
scoring_endpoint = client.deployments.get_scoring_url(created_deployment)

# %%
scoring_endpoint
# Out:
# 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/f7a4026d-88ec-4375-99fe-35bc417dda3e/deployments/968cd041-732e-45f8-84f1-6744ba99dfb9/online'
